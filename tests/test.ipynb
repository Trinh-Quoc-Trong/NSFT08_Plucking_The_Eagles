# %%
class_name = ['f12','f13','f144','f1555',]
print(f'la : f{",".join(class_name)}')
# Out:
# la : ff12,f13,f144,f1555

# %%
x = 'hello'

# %%
import torch


if torch.cuda.is_available():
    print(">>> Đang sử dụng GPU.")
    d_ = torch.device("cuda")

d_
# Out:
# >>> Đang sử dụng GPU.
# device(type='cuda')
